# %%
# from importlib import reload
from tournament import *
# tournament = reload(tournament)

# %run main.py
# Out:
# __main__
# Добро пожаловать в арифметико-ролевую игру с драконами!
# Представьтесь, пожалуйста: refe
# У Вас на пути 3 драконов!
# Вышел черный дракон!
# Вопрос: 17*87
# Ответ:34
# Ошибка!
# ** вам нанесён удар:**
# -15
# Вопрос: 5*74
# Ответ:370
# Верно!
# ** дракон кричит от боли:**
# +10
# Вопрос: 28*90
# Ответ:2520
# Верно!
# ** дракон кричит от боли:**
# +10
# Вопрос: 73*24
# Ответ:1752
# Верно!
# ** дракон кричит от боли:**
# +10
# Вопрос: 78*34
# Ответ:78
# Ошибка!
# ** вам нанесён удар:**
# -15
# Вопрос: 86*25
# Ответ:2150
# Верно!
# ** дракон кричит от боли:**
# +10
# Дракон черный повержен!
#
# Вышел красный дракон!
# Вопрос: 42-7
# Ответ:35
# Верно!
# ** дракон кричит от боли:**
# +10
# Вопрос: 96-92
# Ответ:4
# Верно!
# ** дракон кричит от боли:**
# +10
# Вопрос: 90-2
# Ответ:88
# Верно!
# ** дракон кричит от боли:**
# +10
# Вопрос: 17-83
# Ответ:-66
# Верно!
# ** дракон кричит от боли:**
# +10
# Дракон красный повержен!
#
# Вышел красный дракон!
# Вопрос: 1-16
# ...
