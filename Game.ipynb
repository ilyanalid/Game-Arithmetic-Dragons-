# %%
from tournament import *

print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# __main__
# Добро пожаловать в арифметико-ролевую игру с драконами!
# Представьтесь, пожалуйста: щ
# У Вас на пути 3 драконов!
# Вышел красный дракон!
# Вопрос: 29-94
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 80-94
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 17-20
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 97-41
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 80-42
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 12-5
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 12-58
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 58-97
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 39-63
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 17-71
# Ответ:0
# Ошибка!
# ** вам нанесён удар... **
# К сожалению, Вы проиграли...
