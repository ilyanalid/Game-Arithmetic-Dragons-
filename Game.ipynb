# %%
# coding: utf-8
# license: GPLv3

from tournament import *

print(__name__)

if __name__ == '__main__':
    start_game()
# Out:
# __main__
# Добро пожаловать в арифметико-ролевую игру с драконами!
# Представьтесь, пожалуйста: d
# У Вас на пути 3 драконов!
# Вышел красный дракон!
# Вопрос: 44-67
# Ответ:d
# Вы ввели недопустимые символы
# Ответ:d3
# Вы ввели недопустимые символы
# Ответ:34
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 93-37
# Ответ:34
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 10-79
# Ответ:43
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 78-15
# Ответ:34
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 31-66
# Ответ:34
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 24-51
# Ответ:23
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 55-70
# Ответ:23
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 61-5
# Ответ:23
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 43-70
# Ответ:23
# Ошибка!
# ** вам нанесён удар... **
# Вопрос: 53-72
# Ответ:23
# Ошибка!
# ** вам нанесён удар... **
# К сожалению, Вы проиграли...
